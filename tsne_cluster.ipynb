# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#resnet34" data-toc-modified-id="resnet34-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>resnet34</a></span></li><li><span><a href="#resnet101" data-toc-modified-id="resnet101-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>resnet101</a></span></li><li><span><a href="#resnet-152" data-toc-modified-id="resnet-152-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>resnet 152</a></span></li><li><span><a href="#vgg" data-toc-modified-id="vgg-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>vgg</a></span></li><li><span><a href="#densenet" data-toc-modified-id="densenet-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>densenet</a></span></li><li><span><a href="#squeezenet" data-toc-modified-id="squeezenet-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>squeezenet</a></span></li><li><span><a href="#alexnet" data-toc-modified-id="alexnet-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>alexnet</a></span></li></ul></div>

# %% [markdown]
# set feature_available = False if feature_vectors dir is empty

# %%
from my_utils import *
from config import MODELS, SAVE_MODELS
import seaborn as sns
sns.set(style = "white")

# %% [markdown]
# ### resnet34

# %%
tsne_visualization("res34", sample_imgs = 1000, feature_available=True)

# %% [markdown]
# ### resnet101

# %%
tsne_visualization("res101", sample_imgs = 1000, feature_available=True)

# %% [markdown]
# ### resnet 152

# %%
tsne_visualization("res152", sample_imgs = 1000, feature_available=True)

# %% [markdown]
# ### vgg

# %%
tsne_visualization("vgg", sample_imgs = 1000, feature_available=True)

# %% [markdown]
# ### densenet

# %%
tsne_visualization("densenet", sample_imgs = 1000, feature_available=False)
# Out:
# 100%|██████████| 100.0/100 [00:03<00:00, 30.08it/s]
# saving feature vectors at  ./feature_vectors/densenet_feature_vec.npy

# %% [markdown]
# ### squeezenet

# %%
tsne_visualization("squeeze", sample_imgs = 1000, feature_available=False)
# Out:
# 100%|██████████| 100.0/100 [00:01<00:00, 67.06it/s]
# saving feature vectors at  ./feature_vectors/squeeze_feature_vec.npy

# %% [markdown]
# ### alexnet

# %%
tsne_visualization("alexnet", sample_imgs = 1000, feature_available=False)
# Out:
# 100%|██████████| 100.0/100 [00:00<00:00, 149.79it/s]
# saving feature vectors at  ./feature_vectors/alexnet_feature_vec.npy
